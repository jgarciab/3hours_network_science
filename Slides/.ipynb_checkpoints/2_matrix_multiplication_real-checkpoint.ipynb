# %%
#Netowrks
import networkx as nx
import igraph as ig

#Viz
import pylab as plt
import seaborn as sns
import matplotlib as mpl

import pandas as pd
import numpy as np

import scipy.sparse as ss

#%matplotlib notebook
# %matplotlib inline

# %%
def plot_network_adj(G, values = None):
    
    if values is None:
        values = nx.degree_centrality(G).values()
    
    norm = mpl.colors.Normalize(vmin=min(values), vmax=max(values), clip=True)
    mapper = mpl.cm.ScalarMappable(norm=norm, cmap=mpl.cm.coolwarm)


    f, (a0, a1, a2) = plt.subplots(1, 3, gridspec_kw={'width_ratios': [1, 1, 0.5]}, figsize=(12,4))

    # NEtwork
    if nx.is_bipartite(G):
        top = [_ for _ in G.nodes() if _[0] != "S"]
        pos = nx.bipartite_layout(G, top)
        node_color = ["cornflowerblue" if node in top else "tomato" for node in G]
    else:
        pos = nx.spring_layout(G, seed = 1)
        node_color = [mapper.to_rgba(i) for i in values]

    nx.draw(G, pos = pos, with_labels = True, node_size=500*np.array(list(values)), edge_color = "darkgray", 
           node_color = node_color, ax = a0)
    
    
    # Adjacency
    df = nx.to_pandas_adjacency(G, nodelist=list(G.nodes()), dtype=int)
    plot_table(a1, df.values, df.index, df.columns)

    A = nx.to_scipy_sparse_array(G, nodelist=list(G.nodes()), weight=1)
    N = len(G.nodes())
    a2.spy(A)
    sns.despine(bottom="True", left=True)
    plt.grid(True)
    #2add the right 
    a2.set_xticks(range(N), G.nodes(), rotation=90)
    a2.set_yticks(range(N), G.nodes())
    plt.tight_layout()

def plot_table(a1, cellText, rowLabels, colLabels):
    cellText = pd.DataFrame(cellText)
    the_table = a1.table(cellText=cellText.values, rowLabels=rowLabels, colLabels=colLabels, loc='center', colLoc = "left", cellColours=(cellText>0).replace({False: "white", True:"cornflowerblue"}).values)
    a1.axis(False) 
    the_table.scale(0.8, 1.6)

    
def adj_to_net(A, d_names = {0: "Alice", 1: "Bob", 2: "John", 3:"Amy", 4:"Mike", 5:"Rose"}):
    G = nx.from_numpy_array(A, create_using=nx.DiGraph())
    G = nx.relabel_nodes(G, d_names)
    return G

def normalize_by_row(A):
    S = 1/A.sum(axis=1)
    Q = ss.csr_array(ss.spdiags(S.T, 0, *A.shape))
    return (Q @ A)

# %%
# Small directed network to understand matrix multiplication
G_dir = nx.from_edgelist([
    ("Alice", "Bob"),
        ("John", "Alice"),
    ("Bob", "John"),
    ("Amy", "John"),
    ("Mike", "John"),
    ("Rose", "Alice"),
    ("Mike", "Rose")
], create_using=nx.DiGraph())

plot_network_adj(G_dir)


# Small undirected network
G_undir = nx.from_edgelist([
    ("Alice", "Bob"),
    ("John", "Alice"),
    ("Bob", "John"),
    ("Amy", "John"),
    ("Mike", "John"),
    ("Rose", "Alice"),
    ("Mike", "Rose")
], create_using=nx.Graph())


plot_network_adj(G_undir)

# %%
# Create some metadata
df = pd.DataFrame([["Alice",10],
                  ["Bob",5],
                  ["John",5],
                  ["Amy",1],
                  ["Mike",10],
                  ["Rose",100]], columns=["Person","Income"])

df
# Out:
#   Person  Income
# 0  Alice      10
# 1    Bob       5
# 2   John       5
# 3    Amy       1
# 4   Mike      10
# 5   Rose     100

# %% [markdown]
# # Exercise 1
# 1.1 Convert the directed network
# - numpy_array
# - scipy_sparse_array
# - pandas_adjacency
# - pandas_edgelist
#
# What are the advantages of each?
#
# 1.2 Create a network object from the pandas adjacency matrix

# %%
#1.1 Convert the network to 
#- numpy_array
#- scipy_sparse_array
#- pandas_adjacency
#- pandas_edgelist

# %%
# 1.2 Create a network object from the pandas adjacency matrix
G = nx.from_numpy_array(A, create_using=nx.DiGraph())
G = nx.relabel_nodes(G, d_names)
plot_network_adj(G)

# %% [markdown]
# # Exercise 2
# What is the average income of the neighbors?

# %%
A = nx.to_scipy_sparse_array(G_undir, nodelist=list(G_undir.nodes()), weight=1)

# %%
sum_income
# Out:
# array([36.66666667,  7.5       ,  4.25      ,  5.        , 52.5       ,
#         5.5       ])

# %%
# Calculate sum of neighbors income
sum_income = A @ df["Income"]

# Divide by number of neighbors to get an average
sum_income = sum_income / A.sum(1)

print(sum_income)
plot_network_adj(G_undir, values=sum_income/10)
# Out:
# [36.66666667  7.5         4.25        5.         52.5         5.5       ]

# %% [markdown]
# # Exercise 3
# Project affiliation networks

# %%
G_bip = nx.from_edgelist([
  ["Alice","S1"],
  ["Bob","S1"],
  ["John","S1"],
  ["Amy","S1"],
  ["Mike","S2"],
  ["Rose","S2"]
], create_using=nx.Graph())

plot_network_adj(G_bip)

# %%
# Proyect (easy option)
G_proj = bipartite.projected_graph(G_bip, ["Alice","Bob","John","Amy","Mike","Rose"])
plot_network_adj(G_proj)

# %%
# Extract the two submatrixes
A = nx.to_scipy_sparse_array(G_bip, nodelist=["Alice","Bob","John","Amy","Mike","Rose","S1","S2"])

A_people = A[:6,:][:,-2:]
A_school = A_people.T

plt.figure(figsize=(12,4))
a1 = plt.subplot(131)
plot_table(a1, A_people.todense(), ["Alice","Bob","John","Amy","Mike","Rose"], ["S1","S2"])
a2 = plt.subplot(132)
plot_table(a2, A_school.todense(),  ["S1","S2"], ["Alice","Bob","John","Amy","Mike","Rose"])
a3 = plt.subplot(133)
plot_table(a3, (A_people @ A_school).todense(),  ["Alice","Bob","John","Amy","Mike","Rose"], ["Alice","Bob","John","Amy","Mike","Rose"])

# %%
# Proyect via multiplication
G_proj = adj_to_net(A_people @ A_school)
G_proj.remove_edges_from(nx.selfloop_edges(G_proj))


plot_network_adj(G_proj)

# %% [markdown]
# # Exercise 4: Matrix multiplication
# Interpretation as number of routes
# - Number of nodes 2 steps away
# - Number of nodes 3 steps away
# - Number of triangles directed
# - Number of triangles undirected

# %%
# Number of paths to go from node i to node j in x steps

#x = 1
plot_network_adj(G_dir)
A = nx.to_scipy_sparse_array(G_dir)

#x = 2
G2 = adj_to_net(A @ A)
plot_network_adj(G2)

#x = 3
G3 = adj_to_net(A @ A @ A)
plot_network_adj(G3)

# %%
# Exercise 5: Number of triangles
path_3 = A**3

#For directed networks
path_3 = path_3.diagonal()
#For undirected newtorks there are two directions
#path_3 = path_3.diagonal() / 2
path_3
# Out:
# array([1, 1, 1, 0, 0, 0])

# %%
# Interpreation as message passing/random walking. STart with a 1 somewhere, see where it goes after

# %% [markdown]
# # Exercise 5 (Eszter)
# - Sum salary of parents
# - Linking to neighbors parents
# - Average nighbors salary

# %% [markdown]
# # Exercise 6
# - Assortativity and clustering

# %%
# number of friedns who are friends among themselves
A = nx.to_scipy_sparse_array(G_undir)

combinations = (A.sum(1) * (A.sum(1)-1))/2
local_cl = path_3 / combinations
local_cl[~np.isfinite(local_cl)] = 0

np.random.seed(3)

plot_network_adj(G_undir, values=0.1+local_cl)


print(list(zip(G_undir.nodes(), local_cl)))
# Out:
# [('Alice', 0.3333333333333333), ('Bob', 1.0), ('John', 0.16666666666666666), ('Amy', 0.0), ('Mike', 0.0), ('Rose', 0.0)]
# /var/folders/hx/nz98f65j615c4ygz7xt694700000gp/T/ipykernel_96985/2068235747.py:5: RuntimeWarning: invalid value encountered in true_divide
#   local_cl = path_3 / combinations

# %%
# Out:
#   Person  Income
# 0  Alice      10
# 1    Bob       5
# 2   John       5
# 3    Amy       1
# 4   Mike       1
# 5   Rose     100

# %%
A = nx.to_scipy_sparse_array(G_undir)

# %%
#https://pdf.sciencedirectassets.com/280203/1-s2.0-S1877050914X00062/1-s2.0-S1877050914004062/main.pdf?X-Amz-Security-Token=IQoJb3JpZ2luX2VjELj%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEaCXVzLWVhc3QtMSJIMEYCIQCTxrR6Yf4OMWi10aiWskEw8paDn%2Fe51ktLr%2BPBcRjBHgIhAOvUS%2Fhgj7p60cyNuejLVGBcnHrYr%2FS1ZVCAuCHJ06gnKtsECMH%2F%2F%2F%2F%2F%2F%2F%2F%2F%2FwEQBBoMMDU5MDAzNTQ2ODY1IgwXOO5cdfGFbOXHyj4qrwSlpreBRkMXa6oOrc6Q5edc1BqbbxvyiEf7OCCLJCGuYIXyRxrYVhWzF7klPnWIYwPXapeUqyqj7Ftf93QLgLwDYPFYaQOnQgxPZzNqWYtYHZqcdu5v1E8gkISh7NTgmFjMuNeOej0UG1ZC4RBPwpHH%2BA1aDF0WSLGMgQ8mgc63zK%2FvDA9a4Rfz97FICfn2KzHCf%2BJIGcf6iEXMaJ98y1ofAjsEvQ%2BgWGSoaJR59FnqvV9OeZoaxoxZ6w%2F5OntaxRqpLFCd%2FvBdgnq4c8fMhL8A09Y4tiCnzBhyjdZ%2B3D98D8RrDMjZPoKZ81wAuT9xwtV%2BMN667HWcquNu7W7CZQDxTa%2BxXkaXaW9pngYWbBDqDFtbpF%2B7sVzkM7a1KQbPI1tTxqfxluVUQcNxwee4iIW2%2FfzL8zeFVBrTse3U7mYGHJICABlq0JXMyAFUa%2F%2F69fcZGonnB5CvRorILbxsSNuAs%2BdqodwwO7Pf%2FOjau4TwMlpVa2hqnqwuKQ4M2RZdffzhKMq7qIuvptB3290HLoexTNqRpeEvaelvpugcmjyudxTTzLJQ%2BmzuBMsw%2BStNSkeJhz7pNt6FhnOXV4W9x%2FLDuwKWW0bpojpzbt6C1BxTw3t29jZ52Hp5QeaXreHUNspwmkDpLx98zPDKmxNTSE0jg8Ns2XT9w8p9IyZBfNRwSkQRGRHd34esxWsTuWcKpl7vvl2vlt3YhTJrQkwPmE1pEGYJhNKAmp77g7isoXoeMP%2BjrZUGOqgBlj5o66vJYmz3fSDdjfsNiLVR4%2BpupS%2FGsP%2BbpcSBuN6T5l9zZ3vNV9zu8BQM0revZP1SE%2BKnnjOgeyzXhR2aZ9QBL05f3TgUI1RbcSqRrm8v%2F7BwrL1EzuuIqTvyrWHldbuHOa3ZhVXJD527GfbcZYIyuKVSXQ3trrlwFVbs8f1ww6h9km53%2B9eOjX5eCCqVYkasJgEirjPLoPPh9%2B47SRXmJo0o3yrI&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20220616T172210Z&X-Amz-SignedHeaders=host&X-Amz-Expires=300&X-Amz-Credential=ASIAQ3PHCVTY4OEC5SM2%2F20220616%2Fus-east-1%2Fs3%2Faws4_request&X-Amz-Signature=a5fa36bbffed0bd12a786dc825f114d86f74966336e323310e82720d580ddc84&hash=563a9b9dc158345e3daae17d8e6af7767454b4180bb3df8113a87cf236a2f6bf&host=68042c943591013ac2b2430a89b270f6af2c76d8dfd086a07176afe7c76c2c61&pii=S1877050914004062&tid=spdf-eb571a44-7907-4e60-bd2e-308db61521ed&sid=26769edc47e9254027388d339b4608b84fbdgxrqb&type=client&ua=4d5700525d5d0b0156060a&rr=71c539dc9ae7b974
nx.set_node_attributes(G_undir, df.Income, "Income")

# %%
df.Income = [1, 10,10,1,1,10]

# %%
degree = df.Income.values#A.sum(1)
diff_degree = ((A * degree).todense().T / degree)
diff_degree[(A==0).todense()] = 1
a = np.abs(np.log2(diff_degree)).sum(1)/A.sum(1)

a = (a.mean() - a)
# a /= a.std()
a  = (a - a.min())/(a.max() - a.min())
a = 1-a*2
#print(diff_degree.sum(1)/A.sum(1))
#diff_degree = (A * degree).todense().T.mean(1) - df.Income.mean()
#diff_degree[(A==0).todense()] = 0
#diff_degree
# diff_degree = (diff_degree)**2
# max_diff_degree = max_diff_degree**2

#assort2 = np.abs(diff_degree).sum(1)/A.sum(1)
#assort2 = 1-assort2

list(zip(G_undir.nodes(), a,df.Income))#, np.median(diff_degree,1)))#, diff_degree.mean(1), diff_degree.std(1)))
# Out:
# [('Alice', 1.0, 1),
#  ('Bob', -1.0, 10),
#  ('John', 1.1102230246251565e-16, 10),
#  ('Amy', 1.0, 1),
#  ('Mike', 1.0, 1),
#  ('Rose', 1.0, 10)]

# %%
np.log2(diff_degree).round(1)
# Out:
# array([[ 0. , -3.3, -3.3,  0. ,  0. , -3.3],
#        [ 3.3,  0. ,  0. ,  0. ,  0. ,  0. ],
#        [ 3.3,  0. ,  0. ,  3.3,  3.3,  0. ],
#        [ 0. ,  0. , -3.3,  0. ,  0. ,  0. ],
#        [ 0. ,  0. , -3.3,  0. ,  0. , -3.3],
#        [ 3.3,  0. ,  0. ,  0. ,  3.3,  0. ]])

# %%
plot_network_adj(G_undir, values=df.Income/10)

# %%
degree = A.sum(1)
diff_degree = (A * degree).todense().T - degree
diff_degree[(A==0).todense()] = 0
assort = np.abs(diff_degree).sum(1)/degree
assort = assort/np.sum(assort)
assort = (1+nx.degree_assortativity_coefficient(G))/N - assort

assort2 = diff_degree.mean(1)/diff_degree.std()
assort2 = assort2/np.sum(assort2)

list(zip(G_undir.nodes(), np.round(assort2,2), np.round(assort,2), df.Income))
# Out:
# /Users/garci061/miniforge3/envs/networks/lib/python3.10/site-packages/IPython/core/interactiveshell.py:3398: SparseEfficiencyWarning: Comparing a sparse matrix with 0 using == is inefficient, try using != instead.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# [('Alice', -949442166131757.0, -0.05, 10),
#  ('Bob', 2848326498395271.5, -0.1, 5),
#  ('John', -7595537329054056.0, -0.16, 5),
#  ('Amy', 2848326498395271.5, -0.27, 1),
#  ('Mike', 1898884332263514.0, -0.05, 10),
#  ('Rose', 949442166131757.0, 0.01, 100)]

# %% [markdown]
# # Exercise 7
# - Eigenvector (even more advanced)

# %%
# Exercise : Eigenvector centrality, manually

weight = np.ones(N)

for i in range(100):
    # calculate power
    weight =    weight @ A

    # normalize uwing the geometrical mean
    weight = weight / np.sqrt(np.sum(weight**2))
    
print(list(zip(G_undir.nodes(), weight)))

nx.eigenvector_centrality(G_undir)
# Out:
# [('Alice', 0.49816568565363206), ('Bob', 0.40845488054415907), ('John', 0.5634381194270055), ('Amy', 0.21678431148030036), ('Mike', 0.3410115867353848), ('Rose', 0.3228756816201712)]
# {'Alice': 0.49816562620567956,
#  'Bob': 0.4084543148167931,
#  'John': 0.563437771403002,
#  'Amy': 0.21678389847563684,
#  'Mike': 0.3410123357350908,
#  'Rose': 0.32287658256564244}

# %%
# Exercise 4: PAgerank centrality, manually

N = len(G_dir)
A = nx.to_numpy_array(G_dir)
S = 1/A.sum(axis=1)
Q = ss.csr_array(ss.spdiags(S.T, 0, *A.shape))
A_hat = (Q @ A)

weight = np.ones(N)
for i in range(3):
    # calculate power
    weight = 0.85*(weight @ A_hat) + 0.15/N
    print(weight)
    # normalize uwing the geometrical mean
    #weight = weight / np.sqrt(np.sum(weight**2))
    
list(zip(G.nodes(), weight/np.sum(weight)))

#compare with nx.eigenvector_centrality(G)
# Out:
# [1.725 0.875 2.15  0.025 0.025 0.45 ]
# [2.235    1.49125  0.800625 0.025    0.025    0.035625]
# [0.7358125 1.92475   1.3244375 0.025     0.025     0.035625 ]
# [(0, 0.18076155381544606),
#  (1, 0.47283893750959616),
#  (2, 0.325364655304775),
#  (3, 0.006141563027790573),
#  (4, 0.006141563027790573),
#  (5, 0.008751727314601566)]

# %%
nx.pagerank(G_dir)
# Out:
# {'Alice': 0.3153534818017285,
#  'Bob': 0.293052806246324,
#  'John': 0.3059687119519481,
#  'Amy': 0.025,
#  'Mike': 0.025,
#  'Rose': 0.035625000000000004}
